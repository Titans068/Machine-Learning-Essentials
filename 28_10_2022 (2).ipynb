# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("ram_price.csv")
df
# Out:
#      Unnamed: 0     date         price
# 0             0  1957.00  4.110418e+08
# 1             1  1959.00  6.794772e+07
# 2             2  1960.00  5.242880e+06
# 3             3  1965.00  2.642412e+06
# 4             4  1970.00  7.340030e+05
# ..          ...      ...           ...
# 328         328  2015.58  4.500000e-03
# 329         329  2015.67  4.300000e-03
# 330         330  2015.75  4.200000e-03
# 331         331  2015.83  3.800000e-03
# 332         332  2015.92  3.700000e-03
#
# [333 rows x 3 columns]

# %%
plt.semilogy(df.date, df.price)
plt.xlabel("Year")
plt.ylabel("Price in $/Mbyte")
# Out:
# Text(0, 0.5, 'Price in $/Mbyte')

# %%
from sklearn.tree import DecisionTreeRegressor
import numpy as np

# %%
max(df.date)
# Out:
# 2015.92

# %%
train = df.loc[df.date < 2000]
test = df.loc[df.date >= 2000]
x_train = np.array(train.date)[:, np.newaxis].copy()
y_train = train.price.copy()
display(x_train)
display(y_train)
# Out:
# array([[1957.  ],
#        [1959.  ],
#        [1960.  ],
#        [1965.  ],
#        [1970.  ],
#        [1973.  ],
#        [1974.  ],
#        [1975.  ],
#        [1975.08],
#        [1975.25],
#        [1975.75],
#        [1976.  ],
#        [1976.17],
#        [1976.42],
#        [1976.58],
#        [1977.08],
#        [1978.17],
#        [1978.25],
#        [1978.33],
#        [1978.5 ],
#        [1978.58],
#        [1978.75],
#        [1979.  ],
#        [1979.75],
#        [1980.  ],
#        [1981.  ],
#        [1981.58],
#        [1982.  ],
#        [1982.17],
#        [1982.67],
#        [1983.  ],
#        [1983.67],
#        [1984.  ],
#        [1984.58],
#        [1985.  ],
#        [1985.33],
#        [1985.42],
#        [1985.5 ],
#        [1985.58],
#        [1985.67],
#        [1985.83],
#        [1985.92],
#        [1986.  ],
#        [1986.08],
#        [1986.17],
#        [1986.25],
#        [1986.33],
#        [1986.42],
#        [1986.5 ],
#        [1986.58],
# ...

# %%
tree = DecisionTreeRegressor()
tree
# Out:
# DecisionTreeRegressor()

# %%
tree.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
x_all = df.date[:, np.newaxis].copy()
x_all
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   """Entry point for launching an IPython kernel.
# array([[1957.  ],
#        [1959.  ],
#        [1960.  ],
#        [1965.  ],
#        [1970.  ],
#        [1973.  ],
#        [1974.  ],
#        [1975.  ],
#        [1975.08],
#        [1975.25],
#        [1975.75],
#        [1976.  ],
#        [1976.17],
#        [1976.42],
#        [1976.58],
#        [1977.08],
#        [1978.17],
#        [1978.25],
#        [1978.33],
#        [1978.5 ],
#        [1978.58],
#        [1978.75],
#        [1979.  ],
#        [1979.75],
#        [1980.  ],
#        [1981.  ],
#        [1981.58],
#        [1982.  ],
#        [1982.17],
#        [1982.67],
#        [1983.  ],
#        [1983.67],
#        [1984.  ],
#        [1984.58],
# ...

# %%
pred = tree.predict(x_all)
pred
# Out:
# array([4.11041792e+08, 6.79477250e+07, 5.24288000e+06, 2.64241200e+06,
#        7.34003000e+05, 3.99360000e+05, 3.14573000e+05, 4.21888000e+05,
#        1.80224000e+05, 6.75840000e+04, 4.99200000e+04, 4.07040000e+04,
#        4.89600000e+04, 2.30400000e+04, 3.20000000e+04, 3.68000000e+04,
#        2.80000000e+04, 2.94400000e+04, 1.92000000e+04, 2.40000000e+04,
#        1.60000000e+04, 1.52000000e+04, 1.05280000e+04, 6.70400000e+03,
#        6.48000000e+03, 8.80000000e+03, 4.47900000e+03, 3.52000000e+03,
#        4.46400000e+03, 1.98000000e+03, 2.39600000e+03, 1.98000000e+03,
#        1.37900000e+03, 1.33100000e+03, 8.80000000e+02, 7.20000000e+02,
#        5.50000000e+02, 4.20000000e+02, 3.50000000e+02, 3.00000000e+02,
#        3.00000000e+02, 3.00000000e+02, 3.00000000e+02, 3.00000000e+02,
#        3.00000000e+02, 3.00000000e+02, 1.90000000e+02, 1.90000000e+02,
#        1.90000000e+02, 1.90000000e+02, 1.90000000e+02, 1.90000000e+02,
# ...

# %%
plt.semilogy(train.date, train.price, label="Training data")
plt.semilogy(test.date, test.price, label="Training data")
plt.semilogy(df.date, pred, label="Tree prediction")
plt.legend()
